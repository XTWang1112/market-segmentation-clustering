# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
segmentation = pd.read_csv('segmentation.csv')
segmentation
# Out:
#     Satisfaction  Loyalty
# 0              4    -1.33
# 1              6    -0.28
# 2              5    -0.99
# 3              7    -0.29
# 4              4     1.06
# 5              1    -1.66
# 6             10    -0.97
# 7              8    -0.32
# 8              8     1.02
# 9              8     0.68
# 10            10    -0.34
# 11             5     0.39
# 12             5    -1.69
# 13             2     0.67
# 14             7     0.27
# 15             9     1.36
# 16             8     1.38
# 17             7     1.36
# 18             7    -0.34
# 19             9     0.67
# 20            10     1.18
# 21             3    -1.69
# 22             4     1.04
# 23             3    -0.96
# 24             6     1.03
# 25             9    -0.99
# 26            10     0.37
# 27             9     0.03
# 28             3    -1.36
# 29             5     0.73

# %%
plt.scatter(segmentation['Satisfaction'], segmentation['Loyalty'])
plt.ylabel('Loyalty', )
plt.xlabel('Satisfaction')
plt.show()

# %%
x = segmentation.copy()

# %%
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
segmentation['Cluster'] = kmeans.fit_predict(x)
segmentation
# Out:
#     Satisfaction  Loyalty  Cluster
# 0              4    -1.33        1
# 1              6    -0.28        1
# 2              5    -0.99        1
# 3              7    -0.29        0
# 4              4     1.06        1
# 5              1    -1.66        1
# 6             10    -0.97        0
# 7              8    -0.32        0
# 8              8     1.02        0
# 9              8     0.68        0
# 10            10    -0.34        0
# 11             5     0.39        1
# 12             5    -1.69        1
# 13             2     0.67        1
# 14             7     0.27        0
# 15             9     1.36        0
# 16             8     1.38        0
# 17             7     1.36        0
# 18             7    -0.34        0
# 19             9     0.67        0
# 20            10     1.18        0
# 21             3    -1.69        1
# 22             4     1.04        1
# 23             3    -0.96        1
# 24             6     1.03        0
# 25             9    -0.99        0
# ...

# %%
plt.scatter(segmentation['Satisfaction'], segmentation['Loyalty'], c = segmentation['Cluster'], cmap = 'rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
# Out:
# Text(0, 0.5, 'Loyalty')

# %%
x_standard = preprocessing.scale(x)
x_standard
# Out:
# array([[-0.93138063, -1.3318111 ],
#        [-0.15523011, -0.28117124],
#        [-0.54330537, -0.99160391],
#        [ 0.23284516, -0.29117733],
#        [-0.93138063,  1.05964534],
#        [-2.09560642, -1.6620122 ],
#        [ 1.39707095, -0.97159172],
#        [ 0.62092042, -0.32119561],
#        [ 0.62092042,  1.01962097],
#        [ 0.62092042,  0.67941378],
#        [ 1.39707095, -0.3412078 ],
#        [-0.54330537,  0.38923705],
#        [-0.54330537, -1.69203048],
#        [-1.70753116,  0.66940768],
#        [ 0.23284516,  0.26916393],
#        [ 1.00899568,  1.35982816],
#        [ 0.62092042,  1.37984035],
#        [ 0.23284516,  1.35982816],
#        [ 0.23284516, -0.3412078 ],
#        [ 1.00899568,  0.66940768],
#        [ 1.39707095,  1.17971847],
#        [-1.31945589, -1.69203048],
#        [-0.93138063,  1.03963316],
#        [-1.31945589, -0.96158562],
#        [-0.15523011,  1.02962706],
#        [ 1.00899568, -0.99160391],
#        [ 1.39707095,  0.36922486],
# ...

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(i)
    kmeans.fit(x_standard)
    wcss.append(kmeans.inertia_)
    
wcss
# Out:
# [59.999999999999986,
#  29.818973034723143,
#  17.913349527387968,
#  10.247181805928422,
#  7.792695153937187,
#  6.569489487091783,
#  5.326631124753926,
#  4.315662464700004,
#  3.7282834443589534,
#  3.2824218094452555]

# %%
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
new_kmeans = KMeans(4)
new_kmeans.fit(x_standard)
segmentation['Cluster'] = new_kmeans.fit_predict(x_standard)
segmentation
# Out:
#     Satisfaction  Loyalty  Cluster
# 0              4    -1.33        0
# 1              6    -0.28        2
# 2              5    -0.99        0
# 3              7    -0.29        2
# 4              4     1.06        3
# 5              1    -1.66        0
# 6             10    -0.97        2
# 7              8    -0.32        2
# 8              8     1.02        1
# 9              8     0.68        1
# 10            10    -0.34        2
# 11             5     0.39        3
# 12             5    -1.69        0
# 13             2     0.67        3
# 14             7     0.27        2
# 15             9     1.36        1
# 16             8     1.38        1
# 17             7     1.36        1
# 18             7    -0.34        2
# 19             9     0.67        1
# 20            10     1.18        1
# 21             3    -1.69        0
# 22             4     1.04        3
# 23             3    -0.96        0
# 24             6     1.03        3
# 25             9    -0.99        2
# ...

# %%
plt.scatter(segmentation['Satisfaction'], segmentation['Loyalty'], c = segmentation['Cluster'], cmap = 'rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
# Out:
# Text(0, 0.5, 'Loyalty')
